# %% [markdown]
# <a href="https://colab.research.google.com/github/RegNLP/RePASs/blob/main/RIRAG_SimplificityScore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordfreq textstat nltk torch
# Out:
# Collecting wordfreq
#   Downloading wordfreq-3.1.1-py3-none-any.whl.metadata (27 kB)
# Collecting textstat
#   Downloading textstat-0.7.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Collecting ftfy>=6.1 (from wordfreq)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: langcodes>=3.0 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (3.5.0)
# Collecting locate<2.0.0,>=1.1.1 (from wordfreq)
#   Downloading locate-1.1.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (1.1.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.11/dist-packages (from wordfreq) (2024.11.6)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting cmudict (from textstat)
#   Downloading cmudict-1.0.32-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from textstat) (75.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy>=6.1->wordfreq) (0.2.13)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes>=3.0->wordfreq) (1.3.0)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (8.6.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=5->cmudict->textstat) (3.21.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes>=3.0->wordfreq) (1.2.1)
# Downloading wordfreq-3.1.1-py3-none-any.whl (56.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 19.4 MB/s eta 0:00:00
# Downloading textstat-0.7.5-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 9.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.4 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
# Downloading locate-1.1.1-py3-none-any.whl (5.4 kB)
# Downloading cmudict-1.0.32-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 58.4 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 82.6 MB/s eta 0:00:00
# Installing collected packages: pyphen, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, locate, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, cmudict, textstat, nvidia-cusolver-cu12, wordfreq
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed cmudict-1.0.32 ftfy-6.3.1 locate-1.1.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pyphen-0.17.2 textstat-0.7.5 wordfreq-3.1.1

# %%
from wordfreq import zipf_frequency
import textstat, numpy as np, nltk, torch, json, csv, os

# Download required NLTK data if not already present.
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

# A helper function to convert a shift value to a score.
def shift_to_score(shift, target_shift, right_slope=0.25):
    if shift <= target_shift:
        score = shift / (target_shift + 0.001)
    else:
        score = 1.0 - right_slope * (shift - target_shift) / (target_shift + 0.001)
    return np.clip(score, 0, 1.0)

#############################################
# Lexical Simplicity Score
#############################################
class SimplicityLexicalScore:
    def __init__(self, target_shift=0.4, word_change_ratio=0.1):
        self.target_shift = target_shift
        self.word_change_ratio = word_change_ratio  # Expected fraction of word changes
        self.stopws = set(nltk.corpus.stopwords.words("english") + ["might", "would", "``"])

    def word_score_func(self, w):
        return zipf_frequency(w, 'en', wordlist="large")

    def is_good_word(self, w):
        if "'" in w:
            return False
        if len(w) > 30 or len(w) == 1:
            return False
        if w.lower() in self.stopws:
            return False
        if all(c.isdigit() for c in w):
            return False
        return True

    def vocab_shift_score(self, txt1, txt2, printing=False):
        words1 = nltk.tokenize.word_tokenize(txt1)
        words2 = nltk.tokenize.word_tokenize(txt2)
        words1 = set([w.lower() for w in words1 if self.is_good_word(w)])
        words2 = set([w.lower() for w in words2 if self.is_good_word(w)])
        removed_words = words1 - words2
        added_words = words2 - words1
        target_n_words = int(self.word_change_ratio * txt1.count(" "))

        vocab_shift = 0.0
        if target_n_words == 0:
            vocab_shift = 1.0  # No expected shifts yet
        elif len(removed_words) > 0 and len(added_words) > 0:
            added_words_zipfs = [{"w": w, "zipf": self.word_score_func(w)} for w in added_words]
            removed_words_zipfs = [{"w": w, "zipf": self.word_score_func(w)} for w in removed_words]
            added_words_zipfs = sorted(added_words_zipfs, key=lambda x: x['zipf'])
            removed_words_zipfs = sorted(removed_words_zipfs, key=lambda x: x['zipf'])[:target_n_words]

            removed_avg_zipfs = np.mean([x['zipf'] for x in removed_words_zipfs[:target_n_words]])
            added_avg_zipfs = np.mean([x['zipf'] for x in added_words_zipfs[:min(target_n_words, len(removed_words_zipfs))]])
            if printing:
                print("Desired # word swaps: %d" % (target_n_words))
                print("[Avg Zipf: %.3f] Added words:" % (added_avg_zipfs), added_words_zipfs)
                print("[Avg Zipf: %.3f] Removed words:" % (removed_avg_zipfs), removed_words_zipfs)

            vocab_shift = (added_avg_zipfs - removed_avg_zipfs) * len(removed_words_zipfs) / target_n_words

        return vocab_shift, len(added_words), len(removed_words)

    def score(self, sources, generateds, partial=False, printing=False, **kwargs):
        scores = []
        vshifts = []
        n_adds, n_dels = [], []
        for source, generated in zip(sources, generateds):
            if partial:
                source = " ".join(source.split(" ")[:generated.count(" ")])
            vshift, n_add, n_del = self.vocab_shift_score(source, generated, printing=printing)
            score = shift_to_score(vshift, self.target_shift)
            vshifts.append(vshift)
            scores.append(score)
            n_adds.append(n_add)
            n_dels.append(n_del)
        scores = torch.FloatTensor(scores)
        scores = (0.3 + torch.clamp(scores, 0.05, 1.0) * 0.7).tolist()
        if printing:
            print("[vshift]", scores)
        return {"scores": scores, "n_w_adds": n_adds, "n_w_dels": n_dels, "vshifts": vshifts}

#############################################
# Syntactic Simplicity Score
#############################################
class SimplicitySyntacticScore:
    def __init__(self):
        pass

    def rsource2target_shift(self, rsource):
        # A piecewise linear function: the higher the source grade, the more simplification is expected.
        if rsource <= 4.0:
            return 0
        elif rsource <= 12.0:
            return (rsource - 3) * 0.5
        return 4.5 + (rsource - 12) * 0.83

    def readability_shift_score(self, txt1, txt2):
        score1 = textstat.flesch_kincaid_grade(txt1)
        score2 = textstat.flesch_kincaid_grade(txt2)
        return score1, score2

    def score(self, sources, generateds, partial=False, printing=False, **kwargs):
        scores = []
        rshifts, rsources, rtargets = [], [], []
        for source, generated in zip(sources, generateds):
            if partial:
                source = " ".join(source.split(" ")[:generated.count(" ")])
            rsource, rtarget = self.readability_shift_score(source, generated)
            rshift = rsource - rtarget
            target_shift = self.rsource2target_shift(rsource)
            score = shift_to_score(rshift, target_shift)
            rshifts.append(rshift)
            rsources.append(rsource)
            rtargets.append(rtarget)
            scores.append(score)
        scores = torch.FloatTensor(scores)
        scores = (0.05 + torch.clamp(scores, 0.02, 1.0) * 0.95).tolist()
        if printing:
            print("[rshift]", scores)
        return {"scores": scores, "rshifts": rshifts, "rsources": rsources, "rtargets": rtargets}

#############################################
# Main: Compute Simplicity Scores
#############################################
def main():
    # Update these variables with your desired inputs.
    input_json_file = "/content/drive/Othercomputers/MBZUAI/MBZUAI/RIRAG System Submission/12_AUEB NLP Group/submission3/no_gen.json"      # e.g., "data/input.json"
    output_folder_path = "/content/drive/Othercomputers/MBZUAI/MBZUAI/RIRAG Task 2 Simplification Evaluations"      # e.g., "results"
    method_name = "lexico_syntactic_simplicity_scores"
    team_name = "12_AUEB NLP _3"

    # Create final output folder by joining the output folder path, method name, and team name.
    final_output_folder = os.path.join(output_folder_path, method_name, team_name)
    os.makedirs(final_output_folder, exist_ok=True)

    # Load JSON data from the file.
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # If the loaded data is a single JSON object, wrap it in a list.
    if not isinstance(data, list):
        data = [data]

    # Initialize scorers.
    lexical_scorer = SimplicityLexicalScore(target_shift=0.4, word_change_ratio=0.1)
    syntactic_scorer = SimplicitySyntacticScore()

    rows = []
    # Initialize accumulators.
    total_lexical_score = 0
    total_n_adds = 0
    total_n_dels = 0
    total_vshift = 0

    total_syntactic_score = 0
    total_rshift = 0
    total_rsource = 0
    total_rtarget = 0

    count = 0

    for item in data:
        question_id = item.get("QuestionID", "")
        retrieved_passages = item.get("RetrievedPassages", [])
        if not retrieved_passages:
            print(f"Skipping {question_id} due to empty RetrievedPassages")
            raw_text = "No Retrieved Passages Available"
        else:
            raw_text = " ".join(retrieved_passages).strip()

        simplified_text = item.get("Answer", "").strip()
        if not simplified_text:
            print(f"Skipping {question_id} due to empty Answer")
            simplified_text = "No Answer Provided"

        lexical_results = lexical_scorer.score([raw_text], [simplified_text], printing=False)
        syntactic_results = syntactic_scorer.score([raw_text], [simplified_text], printing=False)

        lexical_score = lexical_results["scores"][0]
        n_w_adds = lexical_results["n_w_adds"][0]
        n_w_dels = lexical_results["n_w_dels"][0]
        vshift = lexical_results["vshifts"][0]

        syntactic_score = syntactic_results["scores"][0]
        rshift = syntactic_results["rshifts"][0]
        rsource = syntactic_results["rsources"][0]
        rtarget = syntactic_results["rtargets"][0]

        # Print the results for this item.
        #print(f"Processed QuestionID: {question_id}")
        #print(f"  Lexical Simplicity Score: {lexical_score:.4f} (vshift: {vshift:.4f}, adds: {n_w_adds}, dels: {n_w_dels})")
        #print(f"  Syntactic Simplicity Score: {syntactic_score:.4f} (rshift: {rshift:.4f}, source: {rsource:.4f}, target: {rtarget:.4f})\n")

        row = {
            "QuestionID": question_id,
            "LexicalSimplicityScore": lexical_score,
            "n_w_adds": n_w_adds,
            "n_w_dels": n_w_dels,
            "vshift": vshift,
            "SyntacticSimplicityScore": syntactic_score,
            "rshift": rshift,
            "rsource": rsource,
            "rtarget": rtarget
        }
        rows.append(row)

        total_lexical_score += lexical_score
        total_n_adds += n_w_adds
        total_n_dels += n_w_dels
        total_vshift += vshift

        total_syntactic_score += syntactic_score
        total_rshift += rshift
        total_rsource += rsource
        total_rtarget += rtarget

        count += 1

    #print(f"Processed {count} items.\n")

    # Write individual item results to a CSV file.
    csv_file_path = os.path.join(final_output_folder, "simplicity_scores.csv")
    fieldnames = ["QuestionID", "LexicalSimplicityScore", "n_w_adds", "n_w_dels", "vshift",
                  "SyntacticSimplicityScore", "rshift", "rsource", "rtarget"]
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in rows:
            writer.writerow(row)

    # Compute average scores across all items.
    if count > 0:
        avg_lexical_score = total_lexical_score / count
        avg_n_adds = total_n_adds / count
        avg_n_dels = total_n_dels / count
        avg_vshift = total_vshift / count

        avg_syntactic_score = total_syntactic_score / count
        avg_rshift = total_rshift / count
        avg_rsource = total_rsource / count
        avg_rtarget = total_rtarget / count
    else:
        avg_lexical_score = avg_n_adds = avg_n_dels = avg_vshift = 0
        avg_syntactic_score = avg_rshift = avg_rsource = avg_rtarget = 0

    # Write average scores to a TXT file.
    txt_file_path = os.path.join(final_output_folder, "average_scores.txt")
    with open(txt_file_path, 'w', encoding='utf-8') as txtfile:
        txtfile.write("Average Simplicity Scores:\n\n")
        txtfile.write("Lexical Simplicity:\n")
        txtfile.write(f"Average Lexical Simplicity Score: {avg_lexical_score:.4f}\n")
        txtfile.write(f"Average n_w_adds: {avg_n_adds:.2f}\n")
        txtfile.write(f"Average n_w_dels: {avg_n_dels:.2f}\n")
        txtfile.write(f"Average vshift: {avg_vshift:.4f}\n\n")
        txtfile.write("Syntactic Simplicity:\n")
        txtfile.write(f"Average Syntactic Simplicity Score: {avg_syntactic_score:.4f}\n")
        txtfile.write(f"Average rshift: {avg_rshift:.4f}\n")
        txtfile.write(f"Average rsource: {avg_rsource:.4f}\n")
        txtfile.write(f"Average rtarget: {avg_rtarget:.4f}\n")

        # Print the file content
    with open(txt_file_path, 'r', encoding='utf-8') as txtfile:
        print("\n--- Results ---")
        print(txtfile.read())  # Print the results to the console

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# --- Results ---
# Average Simplicity Scores:
#
# Lexical Simplicity:
# Average Lexical Simplicity Score: 0.3404
# Average n_w_adds: 0.00
# Average n_w_dels: 3.30
# Average vshift: 0.0135
#
# Syntactic Simplicity:
# Average Syntactic Simplicity Score: 0.0783
# Average rshift: -0.8229
# Average rsource: 24.8395
# Average rtarget: 25.6623

# %%
from wordfreq import zipf_frequency
import textstat, numpy as np, nltk, torch, json, csv, os

# Download required NLTK data if not already present.
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

def shift_to_score(shift, target_shift, right_slope=0.25):
    if shift <= target_shift:
        score = shift / (target_shift + 0.001)
    else:
        score = 1.0 - right_slope * (shift - target_shift) / (target_shift + 0.001)
    return np.clip(score, 0, 1.0)

#############################################
# Lexical Simplicity Score
#############################################
class SimplicityLexicalScore:
    def __init__(self, target_shift=0.4, word_change_ratio=0.1):
        self.target_shift = target_shift
        self.word_change_ratio = word_change_ratio  # Expected fraction of word changes
        self.stopws = set(nltk.corpus.stopwords.words("english") + ["might", "would", "``"])

    def word_score_func(self, w):
        return zipf_frequency(w, 'en', wordlist="large")

    def is_good_word(self, w):
        if "'" in w:
            return False
        if len(w) > 30 or len(w) == 1:
            return False
        if w.lower() in self.stopws:
            return False
        if all(c.isdigit() for c in w):
            return False
        return True

    def compute_text_lexical_simplicity(self, text):
        """Compute the average Zipf frequency of the good words in text."""
        words = nltk.tokenize.word_tokenize(text)
        good_words = [w.lower() for w in words if self.is_good_word(w)]
        if not good_words:
            return 0.0
        avg_zipf = np.mean([self.word_score_func(w) for w in good_words])
        return avg_zipf

    def score(self, sources, generateds, partial=False, printing=False, **kwargs):
        results = []
        for source, generated in zip(sources, generateds):
            if partial:
                source = " ".join(source.split(" ")[:generated.count(" ")])
            source_lexical = self.compute_text_lexical_simplicity(source)
            generated_lexical = self.compute_text_lexical_simplicity(generated)
            results.append({
                "source_lexical": source_lexical,
                "generated_lexical": generated_lexical,
                "difference": generated_lexical - source_lexical
            })
        if printing:
            print("[lexical]", results)
        return results

#############################################
# Syntactic Simplicity Score
#############################################
class SimplicitySyntacticScore:
    def __init__(self, max_grade=30):
        self.max_grade = max_grade

    def compute_syntactic_simplicity(self, text):
        """Compute the Flesch-Kincaid grade and convert it to a simplicity score.
           Here, lower grade means simpler text. We convert using:
              simplicity = (max_grade - grade) / max_grade.
           The value is clipped to [0, 1]."""
        grade = textstat.flesch_kincaid_grade(text)
        simplicity = (self.max_grade - grade) / self.max_grade
        simplicity = max(0, min(1, simplicity))
        return grade, simplicity

    def score(self, sources, generateds, partial=False, printing=False, **kwargs):
        results = []
        for source, generated in zip(sources, generateds):
            if partial:
                source = " ".join(source.split(" ")[:generated.count(" ")])
            source_grade, source_simplicity = self.compute_syntactic_simplicity(source)
            generated_grade, generated_simplicity = self.compute_syntactic_simplicity(generated)
            diff_grade = source_grade - generated_grade  # positive if generated is simpler (lower grade)
            results.append({
                "source_grade": source_grade,
                "source_simplicity": source_simplicity,
                "generated_grade": generated_grade,
                "generated_simplicity": generated_simplicity,
                "grade_difference": diff_grade
            })
        if printing:
            print("[syntactic]", results)
        return results

#############################################
# Main: Compute Simplicity Scores
#############################################
def main():
    # Update these variables with your desired inputs.
    input_json_file = "/content/drive/Othercomputers/MBZUAI/MBZUAI/RIRAG System Submission/0_Baseline/retrieval_results.passage_only_bm25_answers.json"      # e.g., "data/input.json"
    output_folder_path = "/content/drive/Othercomputers/MBZUAI/MBZUAI/RIRAG Task 2 Simplification Evaluations"      # e.g., "results"
    method_name = "lexico_syntactic_simplicity_scores_2"
    team_name = "0_Baseline/only_bm25"

    # Create final output folder by joining the output folder path, method name, and team name.
    final_output_folder = os.path.join(output_folder_path, method_name, team_name)
    os.makedirs(final_output_folder, exist_ok=True)

    # Load JSON data from the file.
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    if not isinstance(data, list):
        data = [data]

    # Initialize scorers.
    lexical_scorer = SimplicityLexicalScore(target_shift=0.4, word_change_ratio=0.1)
    syntactic_scorer = SimplicitySyntacticScore(max_grade=30)

    rows = []
    # Accumulators for averages.
    total_source_lex = 0
    total_generated_lex = 0

    total_source_grade = 0
    total_source_simplicity = 0
    total_generated_grade = 0
    total_generated_simplicity = 0
    total_grade_diff = 0

    count = 0

    for item in data:
        question_id = item.get("QuestionID", "")
        retrieved_passages = item.get("RetrievedPassages", [])
        raw_text = " ".join(retrieved_passages)
        simplified_text = item.get("Answer", "")

        lexical_results = lexical_scorer.score([raw_text], [simplified_text], printing=False)[0]
        syntactic_results = syntactic_scorer.score([raw_text], [simplified_text], printing=False)[0]

        source_lex = lexical_results["source_lexical"]
        generated_lex = lexical_results["generated_lexical"]

        source_grade = syntactic_results["source_grade"]
        source_simplicity = syntactic_results["source_simplicity"]
        generated_grade = syntactic_results["generated_grade"]
        generated_simplicity = syntactic_results["generated_simplicity"]
        grade_diff = syntactic_results["grade_difference"]

        # Print the results for this item.
        print(f"Processed QuestionID: {question_id}")
        print(f"  Source Lexical Simplicity: {source_lex:.4f}")
        print(f"  Generated Lexical Simplicity: {generated_lex:.4f}")
        print(f"  Source Syntactic Grade: {source_grade:.4f} -> Syntactic Simplicity: {source_simplicity:.4f}")
        print(f"  Generated Syntactic Grade: {generated_grade:.4f} -> Syntactic Simplicity: {generated_simplicity:.4f}")
        print(f"  Grade Difference (source - generated): {grade_diff:.4f}\n")

        row = {
            "QuestionID": question_id,
            "SourceLexicalSimplicity": source_lex,
            "GeneratedLexicalSimplicity": generated_lex,
            "SourceSyntacticGrade": source_grade,
            "SourceSyntacticSimplicity": source_simplicity,
            "GeneratedSyntacticGrade": generated_grade,
            "GeneratedSyntacticSimplicity": generated_simplicity,
            "GradeDifference": grade_diff
        }
        rows.append(row)

        total_source_lex += source_lex
        total_generated_lex += generated_lex

        total_source_grade += source_grade
        total_source_simplicity += source_simplicity
        total_generated_grade += generated_grade
        total_generated_simplicity += generated_simplicity
        total_grade_diff += grade_diff

        count += 1

    print(f"Processed {count} items.\n")

    # Write individual item results to a CSV file.
    csv_file_path = os.path.join(final_output_folder, "simplicity_scores.csv")
    fieldnames = ["QuestionID", "SourceLexicalSimplicity", "GeneratedLexicalSimplicity",
                  "SourceSyntacticGrade", "SourceSyntacticSimplicity",
                  "GeneratedSyntacticGrade", "GeneratedSyntacticSimplicity",
                  "GradeDifference"]
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in rows:
            writer.writerow(row)

    # Compute average scores across all items.
    if count > 0:
        avg_source_lex = total_source_lex / count
        avg_generated_lex = total_generated_lex / count

        avg_source_grade = total_source_grade / count
        avg_source_simplicity = total_source_simplicity / count
        avg_generated_grade = total_generated_grade / count
        avg_generated_simplicity = total_generated_simplicity / count
        avg_grade_diff = total_grade_diff / count
    else:
        avg_source_lex = avg_generated_lex = 0
        avg_source_grade = avg_source_simplicity = avg_generated_grade = avg_generated_simplicity = avg_grade_diff = 0

    print("Average Scores:")
    print(f"  Lexical Simplicity:")
    print(f"    Source: {avg_source_lex:.4f}")
    print(f"    Generated: {avg_generated_lex:.4f}")
    print(f"  Syntactic Simplicity (converted from Flesch-Kincaid):")
    print(f"    Average Source Grade: {avg_source_grade:.4f} -> Simplicity: {avg_source_simplicity:.4f}")
    print(f"    Average Generated Grade: {avg_generated_grade:.4f} -> Simplicity: {avg_generated_simplicity:.4f}")
    print(f"    Average Grade Difference (source - generated): {avg_grade_diff:.4f}\n")

    # Write average scores to a TXT file.
    txt_file_path = os.path.join(final_output_folder, "average_scores.txt")
    with open(txt_file_path, 'w', encoding='utf-8') as txtfile:
        txtfile.write("Average Simplicity Scores:\n\n")
        txtfile.write("Lexical Simplicity:\n")
        txtfile.write(f"  Source Lexical Simplicity: {avg_source_lex:.4f}\n")
        txtfile.write(f"  Generated Lexical Simplicity: {avg_generated_lex:.4f}\n\n")
        txtfile.write("Syntactic Simplicity (converted from Flesch-Kincaid):\n")
        txtfile.write(f"  Average Source Grade: {avg_source_grade:.4f} -> Simplicity: {avg_source_simplicity:.4f}\n")
        txtfile.write(f"  Average Generated Grade: {avg_generated_grade:.4f} -> Simplicity: {avg_generated_simplicity:.4f}\n")
        txtfile.write(f"  Average Grade Difference (source - generated): {avg_grade_diff:.4f}\n")

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Processed QuestionID: f10933cb-8e29-4f37-82ab-0ea23af317ac
#   Source Lexical Simplicity: 4.4506
#   Generated Lexical Simplicity: 4.4410
#   Source Syntactic Grade: 21.2000 -> Syntactic Simplicity: 0.2933
#   Generated Syntactic Grade: 18.8000 -> Syntactic Simplicity: 0.3733
#   Grade Difference (source - generated): 2.4000
#
# Processed QuestionID: c62ccb81-1712-4b11-8a73-26dcbe710272
#   Source Lexical Simplicity: 4.4576
#   Generated Lexical Simplicity: 4.5870
#   Source Syntactic Grade: 9.7000 -> Syntactic Simplicity: 0.6767
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): -8.6000
#
# Processed QuestionID: 5abfd03e-38d5-4428-a594-e323098cd7d9
#   Source Lexical Simplicity: 4.3178
#   Generated Lexical Simplicity: 4.4408
#   Source Syntactic Grade: 36.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 20.3000 -> Syntactic Simplicity: 0.3233
#   Grade Difference (source - generated): 15.8000
#
# Processed QuestionID: 6957553b-0fc3-4128-8b41-ec47f20bad96
#   Source Lexical Simplicity: 4.2207
#   Generated Lexical Simplicity: 4.4581
#   Source Syntactic Grade: 25.2000 -> Syntactic Simplicity: 0.1600
#   Generated Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Grade Difference (source - generated): 8.7000
#
# Processed QuestionID: 3ccb718d-a7eb-4e1c-979c-79baffa49101
#   Source Lexical Simplicity: 4.7897
#   Generated Lexical Simplicity: 4.6892
#   Source Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Generated Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Grade Difference (source - generated): -1.0000
#
# Processed QuestionID: 2f555d2d-ed98-4b1d-bc87-b451ff9bb838
#   Source Lexical Simplicity: 4.2660
#   Generated Lexical Simplicity: 4.3458
#   Source Syntactic Grade: 15.7000 -> Syntactic Simplicity: 0.4767
#   Generated Syntactic Grade: 18.7000 -> Syntactic Simplicity: 0.3767
#   Grade Difference (source - generated): -3.0000
#
# Processed QuestionID: 2c39b37d-a2d4-4410-b5f9-937344f4a84c
#   Source Lexical Simplicity: 4.6685
#   Generated Lexical Simplicity: 4.5250
#   Source Syntactic Grade: 20.8000 -> Syntactic Simplicity: 0.3067
#   Generated Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Grade Difference (source - generated): 2.9000
#
# Processed QuestionID: ad51018b-7d5e-405c-ae1a-9bdede34a9c3
#   Source Lexical Simplicity: 4.3616
#   Generated Lexical Simplicity: 4.2968
#   Source Syntactic Grade: 12.9000 -> Syntactic Simplicity: 0.5700
#   Generated Syntactic Grade: 15.6000 -> Syntactic Simplicity: 0.4800
#   Grade Difference (source - generated): -2.7000
#
# Processed QuestionID: db8e54b7-6869-4158-aafa-d56e0fac0153
#   Source Lexical Simplicity: 3.9666
#   Generated Lexical Simplicity: 4.2431
#   Source Syntactic Grade: 11.6000 -> Syntactic Simplicity: 0.6133
#   Generated Syntactic Grade: 18.9000 -> Syntactic Simplicity: 0.3700
#   Grade Difference (source - generated): -7.3000
#
# Processed QuestionID: 1c2cf063-c931-499b-8df3-3fc0aee1f191
#   Source Lexical Simplicity: 4.7136
#   Generated Lexical Simplicity: 4.5296
#   Source Syntactic Grade: 17.5000 -> Syntactic Simplicity: 0.4167
#   Generated Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Grade Difference (source - generated): 1.0000
#
# Processed QuestionID: e5554600-1456-457f-8cbf-390862cc0523
#   Source Lexical Simplicity: 4.4935
#   Generated Lexical Simplicity: 4.5894
#   Source Syntactic Grade: 76.3000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 20.8000 -> Syntactic Simplicity: 0.3067
#   Grade Difference (source - generated): 55.5000
#
# Processed QuestionID: 79e6d8cf-2194-47f8-b81d-755452e4dcb3
#   Source Lexical Simplicity: 4.5595
#   Generated Lexical Simplicity: 4.5055
#   Source Syntactic Grade: 32.4000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Grade Difference (source - generated): 17.4000
#
# Processed QuestionID: af6dc6ff-a9f9-4dce-b822-0b60bc58dea7
#   Source Lexical Simplicity: 4.6036
#   Generated Lexical Simplicity: 4.7684
#   Source Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Generated Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Grade Difference (source - generated): -0.3000
#
# Processed QuestionID: b6652ccc-4c4f-4787-ab8b-26dec3f1a8be
#   Source Lexical Simplicity: 4.2655
#   Generated Lexical Simplicity: 4.4489
#   Source Syntactic Grade: 15.1000 -> Syntactic Simplicity: 0.4967
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): -4.3000
#
# Processed QuestionID: b965b61d-2886-4347-be12-e067c4724f9d
#   Source Lexical Simplicity: 4.3848
#   Generated Lexical Simplicity: 4.6237
#   Source Syntactic Grade: 27.5000 -> Syntactic Simplicity: 0.0833
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 12.2000
#
# Processed QuestionID: 1392c4a4-36df-4b54-ade8-e0c50c8a0933
#   Source Lexical Simplicity: 4.6372
#   Generated Lexical Simplicity: 4.4741
#   Source Syntactic Grade: 20.1000 -> Syntactic Simplicity: 0.3300
#   Generated Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Grade Difference (source - generated): 1.5000
#
# Processed QuestionID: 4547971c-d716-44cf-94b9-144f17ef5905
#   Source Lexical Simplicity: 4.0749
#   Generated Lexical Simplicity: 4.2393
#   Source Syntactic Grade: 20.1000 -> Syntactic Simplicity: 0.3300
#   Generated Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Grade Difference (source - generated): 3.5000
#
# Processed QuestionID: ad2ce141-9a7b-49d5-87db-f373f26d6f9c
#   Source Lexical Simplicity: 4.5593
#   Generated Lexical Simplicity: 4.5165
#   Source Syntactic Grade: 16.3000 -> Syntactic Simplicity: 0.4567
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 1.0000
#
# Processed QuestionID: 8050ec27-9d62-4abf-a562-1fa1b5f5dec4
#   Source Lexical Simplicity: 4.6737
#   Generated Lexical Simplicity: 4.5041
#   Source Syntactic Grade: 33.8000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.7000 -> Syntactic Simplicity: 0.3433
#   Grade Difference (source - generated): 14.1000
#
# Processed QuestionID: 4567c30c-cf57-4e03-b9ea-22ea17196416
#   Source Lexical Simplicity: 4.2741
#   Generated Lexical Simplicity: 4.2951
#   Source Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Generated Syntactic Grade: 18.4000 -> Syntactic Simplicity: 0.3867
#   Grade Difference (source - generated): -0.1000
#
# Processed QuestionID: 4e99fc87-1f10-45da-b3c9-50caedde8d16
#   Source Lexical Simplicity: 4.1592
#   Generated Lexical Simplicity: 4.4753
#   Source Syntactic Grade: 13.8000 -> Syntactic Simplicity: 0.5400
#   Generated Syntactic Grade: 14.9000 -> Syntactic Simplicity: 0.5033
#   Grade Difference (source - generated): -1.1000
#
# Processed QuestionID: fe81460b-de21-4c7f-ba30-c5a61a8eb26c
#   Source Lexical Simplicity: 4.2133
#   Generated Lexical Simplicity: 4.2783
#   Source Syntactic Grade: 21.2000 -> Syntactic Simplicity: 0.2933
#   Generated Syntactic Grade: 21.4000 -> Syntactic Simplicity: 0.2867
#   Grade Difference (source - generated): -0.2000
#
# Processed QuestionID: c5dbe24c-1ddc-4d4a-94cf-13424e28b1e5
#   Source Lexical Simplicity: 4.5912
#   Generated Lexical Simplicity: 4.4263
#   Source Syntactic Grade: 22.7000 -> Syntactic Simplicity: 0.2433
#   Generated Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Grade Difference (source - generated): 6.7000
#
# Processed QuestionID: 850fcac3-51f6-480f-8230-968d73abe98b
#   Source Lexical Simplicity: 4.5912
#   Generated Lexical Simplicity: 4.5458
#   Source Syntactic Grade: 22.7000 -> Syntactic Simplicity: 0.2433
#   Generated Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Grade Difference (source - generated): 5.5000
#
# Processed QuestionID: 20407c47-c8a5-44e9-be5a-819e44f34d81
#   Source Lexical Simplicity: 4.6884
#   Generated Lexical Simplicity: 4.6182
#   Source Syntactic Grade: 21.2000 -> Syntactic Simplicity: 0.2933
#   Generated Syntactic Grade: 17.5000 -> Syntactic Simplicity: 0.4167
#   Grade Difference (source - generated): 3.7000
#
# Processed QuestionID: 52b13453-4f9e-4da2-acb6-87df268a5d96
#   Source Lexical Simplicity: 3.9106
#   Generated Lexical Simplicity: 4.1485
#   Source Syntactic Grade: 15.4000 -> Syntactic Simplicity: 0.4867
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): -2.4000
#
# Processed QuestionID: c7f41f82-c366-429b-b818-a43704740c8e
#   Source Lexical Simplicity: 3.7350
#   Generated Lexical Simplicity: 4.3841
#   Source Syntactic Grade: 11.9000 -> Syntactic Simplicity: 0.6033
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): -7.1000
#
# Processed QuestionID: ea42e44d-e3a9-46d1-b6eb-e62835fc7084
#   Source Lexical Simplicity: 4.7150
#   Generated Lexical Simplicity: 4.5874
#   Source Syntactic Grade: 16.4000 -> Syntactic Simplicity: 0.4533
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 1.1000
#
# Processed QuestionID: c530718c-1a78-4c1d-96ed-2130571784c5
#   Source Lexical Simplicity: 4.9750
#   Generated Lexical Simplicity: 4.5120
#   Source Syntactic Grade: 12.0000 -> Syntactic Simplicity: 0.6000
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): -5.4000
#
# Processed QuestionID: 0ce53603-fb31-4a46-84c8-39074c0c7d9c
#   Source Lexical Simplicity: 4.5667
#   Generated Lexical Simplicity: 4.5460
#   Source Syntactic Grade: 33.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.1000 -> Syntactic Simplicity: 0.4633
#   Grade Difference (source - generated): 17.4000
#
# Processed QuestionID: fbd59a56-3307-4a3d-8f6a-aa55ceff7137
#   Source Lexical Simplicity: 4.2935
#   Generated Lexical Simplicity: 4.3300
#   Source Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Generated Syntactic Grade: 19.1000 -> Syntactic Simplicity: 0.3633
#   Grade Difference (source - generated): -1.9000
#
# Processed QuestionID: 1f83dc60-96a0-4dac-9e53-29e3859d9d0f
#   Source Lexical Simplicity: 4.3214
#   Generated Lexical Simplicity: 4.3862
#   Source Syntactic Grade: 13.6000 -> Syntactic Simplicity: 0.5467
#   Generated Syntactic Grade: 18.1000 -> Syntactic Simplicity: 0.3967
#   Grade Difference (source - generated): -4.5000
#
# Processed QuestionID: 630b3b08-bce4-4396-b045-8e74918c6dca
#   Source Lexical Simplicity: 4.5512
#   Generated Lexical Simplicity: 4.6563
#   Source Syntactic Grade: 20.6000 -> Syntactic Simplicity: 0.3133
#   Generated Syntactic Grade: 19.1000 -> Syntactic Simplicity: 0.3633
#   Grade Difference (source - generated): 1.5000
#
# Processed QuestionID: 150ee42c-b7dc-4cc7-9ca9-817c6b10723e
#   Source Lexical Simplicity: 4.3873
#   Generated Lexical Simplicity: 4.3013
#   Source Syntactic Grade: 23.1000 -> Syntactic Simplicity: 0.2300
#   Generated Syntactic Grade: 18.7000 -> Syntactic Simplicity: 0.3767
#   Grade Difference (source - generated): 4.4000
#
# Processed QuestionID: c390f942-3b89-4c7a-a20f-0f0fe395a9cf
#   Source Lexical Simplicity: 4.6913
#   Generated Lexical Simplicity: 4.5730
#   Source Syntactic Grade: 20.9000 -> Syntactic Simplicity: 0.3033
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 3.1000
#
# Processed QuestionID: b1e576cc-f9da-4003-9a5b-2a0f307e26e5
#   Source Lexical Simplicity: 4.6426
#   Generated Lexical Simplicity: 4.6526
#   Source Syntactic Grade: 28.4000 -> Syntactic Simplicity: 0.0533
#   Generated Syntactic Grade: 16.1000 -> Syntactic Simplicity: 0.4633
#   Grade Difference (source - generated): 12.3000
#
# Processed QuestionID: 504c93a8-c6c4-40b2-a8a9-076e4e549d10
#   Source Lexical Simplicity: 4.3417
#   Generated Lexical Simplicity: 4.3818
#   Source Syntactic Grade: 92.7000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.1000 -> Syntactic Simplicity: 0.3633
#   Grade Difference (source - generated): 73.6000
#
# Processed QuestionID: 5b2afc45-b98e-487c-a45f-318b8dcba724
#   Source Lexical Simplicity: 3.9090
#   Generated Lexical Simplicity: 4.4141
#   Source Syntactic Grade: 12.5000 -> Syntactic Simplicity: 0.5833
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): -5.8000
#
# Processed QuestionID: 2a697b32-0fbf-408e-959d-0ad99da569e0
#   Source Lexical Simplicity: 4.8612
#   Generated Lexical Simplicity: 4.6350
#   Source Syntactic Grade: 38.4000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 20.6000
#
# Processed QuestionID: f6108a92-b306-41f8-ba51-5d5135c2b589
#   Source Lexical Simplicity: 4.7677
#   Generated Lexical Simplicity: 4.7029
#   Source Syntactic Grade: 26.9000 -> Syntactic Simplicity: 0.1033
#   Generated Syntactic Grade: 18.9000 -> Syntactic Simplicity: 0.3700
#   Grade Difference (source - generated): 8.0000
#
# Processed QuestionID: 930258ac-aa35-4b0d-9a26-5d95b8369258
#   Source Lexical Simplicity: 4.0749
#   Generated Lexical Simplicity: 4.4018
#   Source Syntactic Grade: 20.1000 -> Syntactic Simplicity: 0.3300
#   Generated Syntactic Grade: 15.8000 -> Syntactic Simplicity: 0.4733
#   Grade Difference (source - generated): 4.3000
#
# Processed QuestionID: cc808ad9-a172-4814-b597-3ed97e9b87bf
#   Source Lexical Simplicity: 4.2936
#   Generated Lexical Simplicity: 4.3324
#   Source Syntactic Grade: 20.9000 -> Syntactic Simplicity: 0.3033
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): 3.5000
#
# Processed QuestionID: 0255aa9c-20a5-4978-8e13-7091a262a789
#   Source Lexical Simplicity: 4.4445
#   Generated Lexical Simplicity: 4.5673
#   Source Syntactic Grade: 20.7000 -> Syntactic Simplicity: 0.3100
#   Generated Syntactic Grade: 20.4000 -> Syntactic Simplicity: 0.3200
#   Grade Difference (source - generated): 0.3000
#
# Processed QuestionID: 3ec9a7ec-207e-4d6a-8f07-91918bb0ed8b
#   Source Lexical Simplicity: 4.6844
#   Generated Lexical Simplicity: 4.5942
#   Source Syntactic Grade: 26.0000 -> Syntactic Simplicity: 0.1333
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): 8.4000
#
# Processed QuestionID: 4d13779e-7816-4cae-9915-e5750dde9344
#   Source Lexical Simplicity: 4.5230
#   Generated Lexical Simplicity: 4.4744
#   Source Syntactic Grade: 66.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Grade Difference (source - generated): 49.6000
#
# Processed QuestionID: 93edc5d5-0d10-41dc-bef6-3b6dc494cd19
#   Source Lexical Simplicity: 4.4607
#   Generated Lexical Simplicity: 4.2314
#   Source Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Generated Syntactic Grade: 19.1000 -> Syntactic Simplicity: 0.3633
#   Grade Difference (source - generated): -1.9000
#
# Processed QuestionID: f513727d-ffd7-4c82-b938-861ca27b4fd6
#   Source Lexical Simplicity: 4.7714
#   Generated Lexical Simplicity: 4.6522
#   Source Syntactic Grade: 15.2000 -> Syntactic Simplicity: 0.4933
#   Generated Syntactic Grade: 15.2000 -> Syntactic Simplicity: 0.4933
#   Grade Difference (source - generated): 0.0000
#
# Processed QuestionID: d16c9dcb-e04e-4978-9781-fbf289b7cbaf
#   Source Lexical Simplicity: 4.8102
#   Generated Lexical Simplicity: 4.1788
#   Source Syntactic Grade: 13.3000 -> Syntactic Simplicity: 0.5567
#   Generated Syntactic Grade: 13.3000 -> Syntactic Simplicity: 0.5567
#   Grade Difference (source - generated): 0.0000
#
# Processed QuestionID: 6f004a8b-ccb3-49ad-bd28-b339206865ef
#   Source Lexical Simplicity: 4.2209
#   Generated Lexical Simplicity: 4.3173
#   Source Syntactic Grade: 21.3000 -> Syntactic Simplicity: 0.2900
#   Generated Syntactic Grade: 16.4000 -> Syntactic Simplicity: 0.4533
#   Grade Difference (source - generated): 4.9000
#
# Processed QuestionID: 42331efd-5776-4891-8bd7-df4d18309d6f
#   Source Lexical Simplicity: 4.5853
#   Generated Lexical Simplicity: 4.4181
#   Source Syntactic Grade: 14.3000 -> Syntactic Simplicity: 0.5233
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): -5.1000
#
# Processed QuestionID: 0de26773-bbf9-4e00-90b3-fe9b53c2abac
#   Source Lexical Simplicity: 4.5669
#   Generated Lexical Simplicity: 4.4267
#   Source Syntactic Grade: 20.9000 -> Syntactic Simplicity: 0.3033
#   Generated Syntactic Grade: 18.5000 -> Syntactic Simplicity: 0.3833
#   Grade Difference (source - generated): 2.4000
#
# Processed QuestionID: cf02d462-6bf4-4044-904a-97bea70bd808
#   Source Lexical Simplicity: 4.7532
#   Generated Lexical Simplicity: 4.6251
#   Source Syntactic Grade: 15.1000 -> Syntactic Simplicity: 0.4967
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): -3.2000
#
# Processed QuestionID: e74a8369-1838-48a3-b269-042e2514d208
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5261
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.8000 -> Syntactic Simplicity: 0.4400
#   Grade Difference (source - generated): 42.3000
#
# Processed QuestionID: bf65a3c4-4546-4f93-8824-8bca0058efa7
#   Source Lexical Simplicity: 4.3977
#   Generated Lexical Simplicity: 4.4269
#   Source Syntactic Grade: 23.3000 -> Syntactic Simplicity: 0.2233
#   Generated Syntactic Grade: 17.1000 -> Syntactic Simplicity: 0.4300
#   Grade Difference (source - generated): 6.2000
#
# Processed QuestionID: fd636e04-16be-4732-9ab1-961781cbf205
#   Source Lexical Simplicity: 4.6131
#   Generated Lexical Simplicity: 4.5649
#   Source Syntactic Grade: 19.3000 -> Syntactic Simplicity: 0.3567
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 1.5000
#
# Processed QuestionID: 033a4b1f-9c8d-4866-aa0b-a6576b726d37
#   Source Lexical Simplicity: 4.6317
#   Generated Lexical Simplicity: 4.5319
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 18.8000 -> Syntactic Simplicity: 0.3733
#   Grade Difference (source - generated): -3.8000
#
# Processed QuestionID: 00ebdd64-28a7-424d-a5fa-4fcde4936464
#   Source Lexical Simplicity: 4.1626
#   Generated Lexical Simplicity: 4.3747
#   Source Syntactic Grade: 11.1000 -> Syntactic Simplicity: 0.6300
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): -7.2000
#
# Processed QuestionID: 452b4bc3-8b36-4da4-a11b-e68cdd2dd96a
#   Source Lexical Simplicity: 4.8357
#   Generated Lexical Simplicity: 4.5904
#   Source Syntactic Grade: 39.2000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.1000 -> Syntactic Simplicity: 0.3633
#   Grade Difference (source - generated): 20.1000
#
# Processed QuestionID: 3a66d6fd-8f0f-466a-90e6-d0fa49444f8e
#   Source Lexical Simplicity: 4.8661
#   Generated Lexical Simplicity: 4.6517
#   Source Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Generated Syntactic Grade: 16.8000 -> Syntactic Simplicity: 0.4400
#   Grade Difference (source - generated): 0.6000
#
# Processed QuestionID: e0b20ec6-bc0a-41ba-a005-ce8c4a961154
#   Source Lexical Simplicity: 4.5725
#   Generated Lexical Simplicity: 4.5443
#   Source Syntactic Grade: 27.3000 -> Syntactic Simplicity: 0.0900
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): 8.3000
#
# Processed QuestionID: 61d17339-ee55-41e4-94c8-a3a4556c1b72
#   Source Lexical Simplicity: 4.2453
#   Generated Lexical Simplicity: 4.2517
#   Source Syntactic Grade: 12.7000 -> Syntactic Simplicity: 0.5767
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): -4.9000
#
# Processed QuestionID: 54cbe14f-9fd3-4af9-a788-a769169f46af
#   Source Lexical Simplicity: 4.7181
#   Generated Lexical Simplicity: 4.6200
#   Source Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 0.4000
#
# Processed QuestionID: 0a4c9387-e1bf-49b3-8950-a8cd68c917bd
#   Source Lexical Simplicity: 4.5011
#   Generated Lexical Simplicity: 4.5497
#   Source Syntactic Grade: 21.7000 -> Syntactic Simplicity: 0.2767
#   Generated Syntactic Grade: 18.5000 -> Syntactic Simplicity: 0.3833
#   Grade Difference (source - generated): 3.2000
#
# Processed QuestionID: adfaf54e-de09-431c-affb-d6a5218d35b2
#   Source Lexical Simplicity: 4.5011
#   Generated Lexical Simplicity: 4.3983
#   Source Syntactic Grade: 61.8000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Grade Difference (source - generated): 45.8000
#
# Processed QuestionID: 07369977-cec5-4085-8e09-c05479e39d9c
#   Source Lexical Simplicity: 4.1941
#   Generated Lexical Simplicity: 4.2962
#   Source Syntactic Grade: 25.5000 -> Syntactic Simplicity: 0.1500
#   Generated Syntactic Grade: 19.6000 -> Syntactic Simplicity: 0.3467
#   Grade Difference (source - generated): 5.9000
#
# Processed QuestionID: b2442c73-4d34-4dfd-8b2a-5c2e3a91b550
#   Source Lexical Simplicity: 4.5305
#   Generated Lexical Simplicity: 4.5479
#   Source Syntactic Grade: 36.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 20.0000 -> Syntactic Simplicity: 0.3333
#   Grade Difference (source - generated): 16.5000
#
# Processed QuestionID: 37b95004-b21c-4451-9d5d-b03fc9a6ded4
#   Source Lexical Simplicity: 4.7272
#   Generated Lexical Simplicity: 4.5061
#   Source Syntactic Grade: 12.7000 -> Syntactic Simplicity: 0.5767
#   Generated Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Grade Difference (source - generated): -3.8000
#
# Processed QuestionID: 219fbded-7a7e-41c5-9866-60902ffa374b
#   Source Lexical Simplicity: 4.7848
#   Generated Lexical Simplicity: 4.7121
#   Source Syntactic Grade: 24.0000 -> Syntactic Simplicity: 0.2000
#   Generated Syntactic Grade: 14.9000 -> Syntactic Simplicity: 0.5033
#   Grade Difference (source - generated): 9.1000
#
# Processed QuestionID: 680998c3-3779-4904-9679-6a34e02ef6cc
#   Source Lexical Simplicity: 4.5082
#   Generated Lexical Simplicity: 4.5726
#   Source Syntactic Grade: 20.7000 -> Syntactic Simplicity: 0.3100
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): 2.4000
#
# Processed QuestionID: a0dafe67-90fd-4a48-84db-d65db6175164
#   Source Lexical Simplicity: 4.1954
#   Generated Lexical Simplicity: 4.3188
#   Source Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Generated Syntactic Grade: 18.9000 -> Syntactic Simplicity: 0.3700
#   Grade Difference (source - generated): -2.4000
#
# Processed QuestionID: b9cec0da-bfb6-434a-b072-4c2ad4659759
#   Source Lexical Simplicity: 4.3543
#   Generated Lexical Simplicity: 4.3510
#   Source Syntactic Grade: 14.0000 -> Syntactic Simplicity: 0.5333
#   Generated Syntactic Grade: 17.0000 -> Syntactic Simplicity: 0.4333
#   Grade Difference (source - generated): -3.0000
#
# Processed QuestionID: c4124f44-3498-4fa9-b5ae-442b6cf3fc54
#   Source Lexical Simplicity: 4.5183
#   Generated Lexical Simplicity: 4.6124
#   Source Syntactic Grade: 32.6000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.6000 -> Syntactic Simplicity: 0.4800
#   Grade Difference (source - generated): 17.0000
#
# Processed QuestionID: 75e69352-649a-4735-ba48-39d9632c26a4
#   Source Lexical Simplicity: 4.5804
#   Generated Lexical Simplicity: 4.5380
#   Source Syntactic Grade: 13.5000 -> Syntactic Simplicity: 0.5500
#   Generated Syntactic Grade: 18.8000 -> Syntactic Simplicity: 0.3733
#   Grade Difference (source - generated): -5.3000
#
# Processed QuestionID: 453ea6e3-5705-415b-a0cb-0e18fd887986
#   Source Lexical Simplicity: 4.2434
#   Generated Lexical Simplicity: 4.3235
#   Source Syntactic Grade: 12.4000 -> Syntactic Simplicity: 0.5867
#   Generated Syntactic Grade: 16.2000 -> Syntactic Simplicity: 0.4600
#   Grade Difference (source - generated): -3.8000
#
# Processed QuestionID: 2346597d-90c3-406a-8201-069358d3c513
#   Source Lexical Simplicity: 4.2722
#   Generated Lexical Simplicity: 4.3973
#   Source Syntactic Grade: 20.3000 -> Syntactic Simplicity: 0.3233
#   Generated Syntactic Grade: 16.7000 -> Syntactic Simplicity: 0.4433
#   Grade Difference (source - generated): 3.6000
#
# Processed QuestionID: 0f28b9ca-2d4c-437f-8d20-cfd0c5e2b8c7
#   Source Lexical Simplicity: 4.3965
#   Generated Lexical Simplicity: 4.4329
#   Source Syntactic Grade: 31.8000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 21.3000 -> Syntactic Simplicity: 0.2900
#   Grade Difference (source - generated): 10.5000
#
# Processed QuestionID: ca319e04-221f-45b6-a4f5-2164cfe259ee
#   Source Lexical Simplicity: 4.5554
#   Generated Lexical Simplicity: 4.4936
#   Source Syntactic Grade: 15.6000 -> Syntactic Simplicity: 0.4800
#   Generated Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Grade Difference (source - generated): -1.6000
#
# Processed QuestionID: 753961e7-5d05-4888-8f3f-7e7c38ef4ae6
#   Source Lexical Simplicity: 4.4094
#   Generated Lexical Simplicity: 4.5415
#   Source Syntactic Grade: 28.7000 -> Syntactic Simplicity: 0.0433
#   Generated Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Grade Difference (source - generated): 10.5000
#
# Processed QuestionID: e2a4bc79-d2ad-4c2c-8b8a-b55c3a94cae4
#   Source Lexical Simplicity: 4.5589
#   Generated Lexical Simplicity: 4.4200
#   Source Syntactic Grade: 16.3000 -> Syntactic Simplicity: 0.4567
#   Generated Syntactic Grade: 14.2000 -> Syntactic Simplicity: 0.5267
#   Grade Difference (source - generated): 2.1000
#
# Processed QuestionID: 7179d115-2b1e-44f7-93a4-0df945566c17
#   Source Lexical Simplicity: 4.5938
#   Generated Lexical Simplicity: 4.4549
#   Source Syntactic Grade: 73.9000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.5000 -> Syntactic Simplicity: 0.3500
#   Grade Difference (source - generated): 54.4000
#
# Processed QuestionID: 62bec524-7993-40a5-bc00-cf1758a1d5ab
#   Source Lexical Simplicity: 4.2016
#   Generated Lexical Simplicity: 4.3644
#   Source Syntactic Grade: 20.2000 -> Syntactic Simplicity: 0.3267
#   Generated Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Grade Difference (source - generated): 2.3000
#
# Processed QuestionID: e1a575e4-f57c-4e70-9f61-e7616f3e447c
#   Source Lexical Simplicity: 4.5188
#   Generated Lexical Simplicity: 4.6747
#   Source Syntactic Grade: 13.5000 -> Syntactic Simplicity: 0.5500
#   Generated Syntactic Grade: 17.2000 -> Syntactic Simplicity: 0.4267
#   Grade Difference (source - generated): -3.7000
#
# Processed QuestionID: add3763a-1ae2-4931-a432-b73cade3d3f4
#   Source Lexical Simplicity: 4.4332
#   Generated Lexical Simplicity: 4.4846
#   Source Syntactic Grade: 24.4000 -> Syntactic Simplicity: 0.1867
#   Generated Syntactic Grade: 22.1000 -> Syntactic Simplicity: 0.2633
#   Grade Difference (source - generated): 2.3000
#
# Processed QuestionID: c4d0aff5-b78f-4421-9b27-17550004b9b7
#   Source Lexical Simplicity: 4.5027
#   Generated Lexical Simplicity: 4.5199
#   Source Syntactic Grade: 27.5000 -> Syntactic Simplicity: 0.0833
#   Generated Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Grade Difference (source - generated): 8.9000
#
# Processed QuestionID: 53c32544-04d3-4d74-a4f2-8e7add8dd221
#   Source Lexical Simplicity: 4.3407
#   Generated Lexical Simplicity: 4.3064
#   Source Syntactic Grade: 23.8000 -> Syntactic Simplicity: 0.2067
#   Generated Syntactic Grade: 17.0000 -> Syntactic Simplicity: 0.4333
#   Grade Difference (source - generated): 6.8000
#
# Processed QuestionID: 181dd8c7-624e-4675-a449-d67da9670e2a
#   Source Lexical Simplicity: 4.3327
#   Generated Lexical Simplicity: 4.2771
#   Source Syntactic Grade: 26.1000 -> Syntactic Simplicity: 0.1300
#   Generated Syntactic Grade: 21.6000 -> Syntactic Simplicity: 0.2800
#   Grade Difference (source - generated): 4.5000
#
# Processed QuestionID: 5877ba27-bead-4426-ae9b-2bef9a855d9b
#   Source Lexical Simplicity: 4.5244
#   Generated Lexical Simplicity: 4.4893
#   Source Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Generated Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Grade Difference (source - generated): -0.7000
#
# Processed QuestionID: 6b510a51-718a-4272-8cec-07823081a123
#   Source Lexical Simplicity: 4.9750
#   Generated Lexical Simplicity: 4.6513
#   Source Syntactic Grade: 12.0000 -> Syntactic Simplicity: 0.6000
#   Generated Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Grade Difference (source - generated): -4.0000
#
# Processed QuestionID: 67737e14-96ed-4c3c-9b41-1bffb9953582
#   Source Lexical Simplicity: 4.5174
#   Generated Lexical Simplicity: 4.4890
#   Source Syntactic Grade: 31.9000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 18.1000 -> Syntactic Simplicity: 0.3967
#   Grade Difference (source - generated): 13.8000
#
# Processed QuestionID: a0575693-4c36-4e4a-bc31-7f467a29ad22
#   Source Lexical Simplicity: 4.6087
#   Generated Lexical Simplicity: 4.6245
#   Source Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Generated Syntactic Grade: 16.4000 -> Syntactic Simplicity: 0.4533
#   Grade Difference (source - generated): 1.9000
#
# Processed QuestionID: 43f4338f-8d5d-40b5-8465-93bfed85e404
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5091
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.1000 -> Syntactic Simplicity: 0.4300
#   Grade Difference (source - generated): 42.0000
#
# Processed QuestionID: 80e4aa1b-516a-4f1a-97cc-1240a93c70a1
#   Source Lexical Simplicity: 4.1882
#   Generated Lexical Simplicity: 4.0449
#   Source Syntactic Grade: 79.8000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Grade Difference (source - generated): 61.6000
#
# Processed QuestionID: 985c5d04-c1e9-4655-b021-6109bb925531
#   Source Lexical Simplicity: 4.5414
#   Generated Lexical Simplicity: 4.4985
#   Source Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): -3.0000
#
# Processed QuestionID: cb4c7ebb-dd80-4fab-a8b1-58b415c01a6e
#   Source Lexical Simplicity: 4.4158
#   Generated Lexical Simplicity: 4.2397
#   Source Syntactic Grade: 24.8000 -> Syntactic Simplicity: 0.1733
#   Generated Syntactic Grade: 18.1000 -> Syntactic Simplicity: 0.3967
#   Grade Difference (source - generated): 6.7000
#
# Processed QuestionID: 326b56d6-ad5b-42ec-aadd-3f227b236ea1
#   Source Lexical Simplicity: 4.2675
#   Generated Lexical Simplicity: 4.4748
#   Source Syntactic Grade: 18.9000 -> Syntactic Simplicity: 0.3700
#   Generated Syntactic Grade: 21.4000 -> Syntactic Simplicity: 0.2867
#   Grade Difference (source - generated): -2.5000
#
# Processed QuestionID: 11decc39-563c-4b00-a0ca-52af9df72fdf
#   Source Lexical Simplicity: 4.2077
#   Generated Lexical Simplicity: 4.3636
#   Source Syntactic Grade: 14.1000 -> Syntactic Simplicity: 0.5300
#   Generated Syntactic Grade: 15.5000 -> Syntactic Simplicity: 0.4833
#   Grade Difference (source - generated): -1.4000
#
# Processed QuestionID: 56355ff1-4ca5-4520-b2f8-c58e0da45d45
#   Source Lexical Simplicity: 4.6688
#   Generated Lexical Simplicity: 4.6344
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): -4.0000
#
# Processed QuestionID: 8019738d-c5b2-4201-bbb5-d21192eb3d97
#   Source Lexical Simplicity: 4.3592
#   Generated Lexical Simplicity: 4.3288
#   Source Syntactic Grade: 22.9000 -> Syntactic Simplicity: 0.2367
#   Generated Syntactic Grade: 16.8000 -> Syntactic Simplicity: 0.4400
#   Grade Difference (source - generated): 6.1000
#
# Processed QuestionID: 2565e627-ea62-48a8-9d15-5435f494335b
#   Source Lexical Simplicity: 4.2681
#   Generated Lexical Simplicity: 4.3551
#   Source Syntactic Grade: 22.8000 -> Syntactic Simplicity: 0.2400
#   Generated Syntactic Grade: 15.8000 -> Syntactic Simplicity: 0.4733
#   Grade Difference (source - generated): 7.0000
#
# Processed QuestionID: 581bcee7-e68b-474d-9287-5cb2ebfb06b9
#   Source Lexical Simplicity: 4.2434
#   Generated Lexical Simplicity: 4.2976
#   Source Syntactic Grade: 12.4000 -> Syntactic Simplicity: 0.5867
#   Generated Syntactic Grade: 17.3000 -> Syntactic Simplicity: 0.4233
#   Grade Difference (source - generated): -4.9000
#
# Processed QuestionID: 37a57f63-435d-47b9-8fe0-1bbef51b2133
#   Source Lexical Simplicity: 3.8675
#   Generated Lexical Simplicity: 4.6090
#   Source Syntactic Grade: 16.7000 -> Syntactic Simplicity: 0.4433
#   Generated Syntactic Grade: 17.3000 -> Syntactic Simplicity: 0.4233
#   Grade Difference (source - generated): -0.6000
#
# Processed QuestionID: 76af2154-a97e-4fd1-9e8d-c39ec0ac12a6
#   Source Lexical Simplicity: 4.7919
#   Generated Lexical Simplicity: 4.6694
#   Source Syntactic Grade: 12.6000 -> Syntactic Simplicity: 0.5800
#   Generated Syntactic Grade: 17.5000 -> Syntactic Simplicity: 0.4167
#   Grade Difference (source - generated): -4.9000
#
# Processed QuestionID: 7066f86e-24a1-4a16-ad40-babaf9f427d5
#   Source Lexical Simplicity: 4.2106
#   Generated Lexical Simplicity: 4.4937
#   Source Syntactic Grade: 21.3000 -> Syntactic Simplicity: 0.2900
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): 3.7000
#
# Processed QuestionID: 1f217a41-49ca-451b-a842-7e842bc8ab1f
#   Source Lexical Simplicity: 4.3932
#   Generated Lexical Simplicity: 4.3588
#   Source Syntactic Grade: 16.3000 -> Syntactic Simplicity: 0.4567
#   Generated Syntactic Grade: 20.3000 -> Syntactic Simplicity: 0.3233
#   Grade Difference (source - generated): -4.0000
#
# Processed QuestionID: 9efa0ea2-b25f-463b-8ee8-9516230c1ebe
#   Source Lexical Simplicity: 4.3261
#   Generated Lexical Simplicity: 4.2467
#   Source Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): -2.5000
#
# Processed QuestionID: 6730b35e-06bd-4ad2-8b38-92a940e9ed78
#   Source Lexical Simplicity: 3.8308
#   Generated Lexical Simplicity: 4.3449
#   Source Syntactic Grade: 20.5000 -> Syntactic Simplicity: 0.3167
#   Generated Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Grade Difference (source - generated): 3.9000
#
# Processed QuestionID: e5076c68-f40b-4d7f-8339-d8ebb25f9908
#   Source Lexical Simplicity: 4.4094
#   Generated Lexical Simplicity: 4.3963
#   Source Syntactic Grade: 28.7000 -> Syntactic Simplicity: 0.0433
#   Generated Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Grade Difference (source - generated): 10.5000
#
# Processed QuestionID: ee797a3e-38d9-4ec9-ab7f-dc4b753ed232
#   Source Lexical Simplicity: 4.6563
#   Generated Lexical Simplicity: 4.5871
#   Source Syntactic Grade: 12.9000 -> Syntactic Simplicity: 0.5700
#   Generated Syntactic Grade: 20.0000 -> Syntactic Simplicity: 0.3333
#   Grade Difference (source - generated): -7.1000
#
# Processed QuestionID: faff73ba-43c3-493f-9e3e-1e1c724777ea
#   Source Lexical Simplicity: 4.2517
#   Generated Lexical Simplicity: 4.2720
#   Source Syntactic Grade: 22.4000 -> Syntactic Simplicity: 0.2533
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): 3.4000
#
# Processed QuestionID: 99662d91-2dcd-4589-ad8b-45dc27a01d57
#   Source Lexical Simplicity: 4.2963
#   Generated Lexical Simplicity: 4.4290
#   Source Syntactic Grade: 34.9000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Grade Difference (source - generated): 17.2000
#
# Processed QuestionID: b7e1048f-e623-4c76-8f01-c64219c34ddf
#   Source Lexical Simplicity: 4.6281
#   Generated Lexical Simplicity: 4.6023
#   Source Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Generated Syntactic Grade: 19.7000 -> Syntactic Simplicity: 0.3433
#   Grade Difference (source - generated): -2.8000
#
# Processed QuestionID: dc09cc72-8300-4823-a0dc-5bf919a2ae5f
#   Source Lexical Simplicity: 3.8244
#   Generated Lexical Simplicity: 4.0073
#   Source Syntactic Grade: 41.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 20.1000 -> Syntactic Simplicity: 0.3300
#   Grade Difference (source - generated): 21.4000
#
# Processed QuestionID: ee9725bb-d411-4aff-bd05-8f3a4997bf33
#   Source Lexical Simplicity: 4.8005
#   Generated Lexical Simplicity: 4.7324
#   Source Syntactic Grade: 20.9000 -> Syntactic Simplicity: 0.3033
#   Generated Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Grade Difference (source - generated): 3.2000
#
# Processed QuestionID: ab99203d-a1b2-4f14-ae44-903e5082175e
#   Source Lexical Simplicity: 4.6836
#   Generated Lexical Simplicity: 4.3688
#   Source Syntactic Grade: 12.5000 -> Syntactic Simplicity: 0.5833
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): -4.9000
#
# Processed QuestionID: c99f7ef1-7b7e-4a69-8528-3ac046f925dc
#   Source Lexical Simplicity: 4.6513
#   Generated Lexical Simplicity: 4.5277
#   Source Syntactic Grade: 19.3000 -> Syntactic Simplicity: 0.3567
#   Generated Syntactic Grade: 16.1000 -> Syntactic Simplicity: 0.4633
#   Grade Difference (source - generated): 3.2000
#
# Processed QuestionID: e8db3b67-8beb-48ab-ba2d-c9998be17948
#   Source Lexical Simplicity: 4.4653
#   Generated Lexical Simplicity: 4.5204
#   Source Syntactic Grade: 22.1000 -> Syntactic Simplicity: 0.2633
#   Generated Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Grade Difference (source - generated): 5.5000
#
# Processed QuestionID: 21aa52e2-e6ea-49ae-bf84-1d71fe4b779e
#   Source Lexical Simplicity: 4.6077
#   Generated Lexical Simplicity: 4.4896
#   Source Syntactic Grade: 24.1000 -> Syntactic Simplicity: 0.1967
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 6.3000
#
# Processed QuestionID: e1968d34-f906-45dc-b875-77fb06be1272
#   Source Lexical Simplicity: 3.6432
#   Generated Lexical Simplicity: 4.2781
#   Source Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): -1.1000
#
# Processed QuestionID: e1ec2618-4ab4-4455-989a-050fa31212ef
#   Source Lexical Simplicity: 4.4943
#   Generated Lexical Simplicity: 4.3371
#   Source Syntactic Grade: 32.2000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 18.0000 -> Syntactic Simplicity: 0.4000
#   Grade Difference (source - generated): 14.2000
#
# Processed QuestionID: 6a1da266-e72e-44b8-b245-8dc0d8e25538
#   Source Lexical Simplicity: 4.3469
#   Generated Lexical Simplicity: 4.5559
#   Source Syntactic Grade: 14.2000 -> Syntactic Simplicity: 0.5267
#   Generated Syntactic Grade: 14.8000 -> Syntactic Simplicity: 0.5067
#   Grade Difference (source - generated): -0.6000
#
# Processed QuestionID: 454a2632-22da-4872-8969-ba768e9d6569
#   Source Lexical Simplicity: 4.0393
#   Generated Lexical Simplicity: 4.3591
#   Source Syntactic Grade: 12.4000 -> Syntactic Simplicity: 0.5867
#   Generated Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Grade Difference (source - generated): -4.5000
#
# Processed QuestionID: aac8e8f3-ea37-4821-a09f-5f70561abae1
#   Source Lexical Simplicity: 4.5277
#   Generated Lexical Simplicity: 4.3059
#   Source Syntactic Grade: 12.1000 -> Syntactic Simplicity: 0.5967
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): -5.7000
#
# Processed QuestionID: fbcf40ea-de08-4951-b8f0-be8214410e1f
#   Source Lexical Simplicity: 4.6979
#   Generated Lexical Simplicity: 4.5087
#   Source Syntactic Grade: 36.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 21.2000
#
# Processed QuestionID: cae33706-9752-40b5-b19c-64e3e6e3863d
#   Source Lexical Simplicity: 4.7844
#   Generated Lexical Simplicity: 4.6458
#   Source Syntactic Grade: 20.3000 -> Syntactic Simplicity: 0.3233
#   Generated Syntactic Grade: 17.5000 -> Syntactic Simplicity: 0.4167
#   Grade Difference (source - generated): 2.8000
#
# Processed QuestionID: 3672b1ed-dc66-4677-a496-0f8b916d8034
#   Source Lexical Simplicity: 4.4503
#   Generated Lexical Simplicity: 4.2668
#   Source Syntactic Grade: 11.7000 -> Syntactic Simplicity: 0.6100
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): -6.1000
#
# Processed QuestionID: abd3b9f2-d4ec-4fe8-8921-3aa41bc657a1
#   Source Lexical Simplicity: 4.3717
#   Generated Lexical Simplicity: 4.6000
#   Source Syntactic Grade: 18.1000 -> Syntactic Simplicity: 0.3967
#   Generated Syntactic Grade: 22.1000 -> Syntactic Simplicity: 0.2633
#   Grade Difference (source - generated): -4.0000
#
# Processed QuestionID: 6e38a689-7e4a-400b-a05d-e5cf1e58bf3d
#   Source Lexical Simplicity: 4.3379
#   Generated Lexical Simplicity: 4.4713
#   Source Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Generated Syntactic Grade: 20.5000 -> Syntactic Simplicity: 0.3167
#   Grade Difference (source - generated): -3.6000
#
# Processed QuestionID: 94058218-eb5d-410d-9d6f-e59efcf6945d
#   Source Lexical Simplicity: 4.5100
#   Generated Lexical Simplicity: 4.4993
#   Source Syntactic Grade: 51.7000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): 34.1000
#
# Processed QuestionID: 350898c6-6d61-428b-93ba-7ea0abea88f8
#   Source Lexical Simplicity: 4.8337
#   Generated Lexical Simplicity: 4.4924
#   Source Syntactic Grade: 16.3000 -> Syntactic Simplicity: 0.4567
#   Generated Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Grade Difference (source - generated): -1.6000
#
# Processed QuestionID: 7bbd1ca7-247b-49ef-b487-39e776e83222
#   Source Lexical Simplicity: 4.5696
#   Generated Lexical Simplicity: 4.4947
#   Source Syntactic Grade: 24.1000 -> Syntactic Simplicity: 0.1967
#   Generated Syntactic Grade: 18.4000 -> Syntactic Simplicity: 0.3867
#   Grade Difference (source - generated): 5.7000
#
# Processed QuestionID: 802c01eb-490e-4267-8e76-31ec277c5dc9
#   Source Lexical Simplicity: 4.3926
#   Generated Lexical Simplicity: 4.3996
#   Source Syntactic Grade: 20.1000 -> Syntactic Simplicity: 0.3300
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): 1.1000
#
# Processed QuestionID: cf2816c2-c5e1-4c81-bd07-d2b7898e992f
#   Source Lexical Simplicity: 4.2016
#   Generated Lexical Simplicity: 4.2015
#   Source Syntactic Grade: 20.2000 -> Syntactic Simplicity: 0.3267
#   Generated Syntactic Grade: 21.1000 -> Syntactic Simplicity: 0.2967
#   Grade Difference (source - generated): -0.9000
#
# Processed QuestionID: d9181552-a6bd-472a-9677-9a29dd8ae9c6
#   Source Lexical Simplicity: 4.3527
#   Generated Lexical Simplicity: 4.3603
#   Source Syntactic Grade: 20.4000 -> Syntactic Simplicity: 0.3200
#   Generated Syntactic Grade: 18.0000 -> Syntactic Simplicity: 0.4000
#   Grade Difference (source - generated): 2.4000
#
# Processed QuestionID: 72282d3c-edfa-44ce-8d3f-c1bba5bfc5ff
#   Source Lexical Simplicity: 4.3236
#   Generated Lexical Simplicity: 4.2132
#   Source Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Generated Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Grade Difference (source - generated): 2.3000
#
# Processed QuestionID: d8d60f34-bfa2-40e6-92f2-af355b20a1a1
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5778
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 14.8000 -> Syntactic Simplicity: 0.5067
#   Grade Difference (source - generated): 44.3000
#
# Processed QuestionID: 29fa55f9-2dd1-46e5-a681-cbb2c84affd7
#   Source Lexical Simplicity: 4.5356
#   Generated Lexical Simplicity: 4.6301
#   Source Syntactic Grade: 12.5000 -> Syntactic Simplicity: 0.5833
#   Generated Syntactic Grade: 16.4000 -> Syntactic Simplicity: 0.4533
#   Grade Difference (source - generated): -3.9000
#
# Processed QuestionID: 6439587e-f47f-4e56-9325-52e3f089368e
#   Source Lexical Simplicity: 4.3436
#   Generated Lexical Simplicity: 4.4681
#   Source Syntactic Grade: 13.1000 -> Syntactic Simplicity: 0.5633
#   Generated Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Grade Difference (source - generated): -2.9000
#
# Processed QuestionID: f58effbd-6405-44a6-b9e1-492ac7423555
#   Source Lexical Simplicity: 3.9863
#   Generated Lexical Simplicity: 4.2240
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Grade Difference (source - generated): -3.6000
#
# Processed QuestionID: 7df10e93-c05d-4c21-b806-01a8c9731fd4
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5510
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): 39.7000
#
# Processed QuestionID: 97394e61-3d0b-4a2c-a52d-53ef9c727016
#   Source Lexical Simplicity: 4.8612
#   Generated Lexical Simplicity: 4.7034
#   Source Syntactic Grade: 38.4000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.4000 -> Syntactic Simplicity: 0.4533
#   Grade Difference (source - generated): 22.0000
#
# Processed QuestionID: 06504264-a1bf-403a-8c9a-3684786f05cb
#   Source Lexical Simplicity: 4.6109
#   Generated Lexical Simplicity: 4.4431
#   Source Syntactic Grade: 26.7000 -> Syntactic Simplicity: 0.1100
#   Generated Syntactic Grade: 19.2000 -> Syntactic Simplicity: 0.3600
#   Grade Difference (source - generated): 7.5000
#
# Processed QuestionID: 2b526fdc-4c41-4a8d-aa4d-68984e9fbe37
#   Source Lexical Simplicity: 4.5934
#   Generated Lexical Simplicity: 4.5330
#   Source Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Generated Syntactic Grade: 15.7000 -> Syntactic Simplicity: 0.4767
#   Grade Difference (source - generated): 0.8000
#
# Processed QuestionID: b0ab543e-e89a-4a1e-b2cb-b65d989dec96
#   Source Lexical Simplicity: 4.4646
#   Generated Lexical Simplicity: 4.3783
#   Source Syntactic Grade: 27.9000 -> Syntactic Simplicity: 0.0700
#   Generated Syntactic Grade: 23.2000 -> Syntactic Simplicity: 0.2267
#   Grade Difference (source - generated): 4.7000
#
# Processed QuestionID: 268b52b4-8682-4b75-b5e2-3bda4970631d
#   Source Lexical Simplicity: 4.6701
#   Generated Lexical Simplicity: 4.5943
#   Source Syntactic Grade: 11.9000 -> Syntactic Simplicity: 0.6033
#   Generated Syntactic Grade: 14.2000 -> Syntactic Simplicity: 0.5267
#   Grade Difference (source - generated): -2.3000
#
# Processed QuestionID: c5dbc7a5-f6fe-4523-915b-1d3db40e448e
#   Source Lexical Simplicity: 4.5676
#   Generated Lexical Simplicity: 4.6261
#   Source Syntactic Grade: 42.9000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 27.6000
#
# Processed QuestionID: a538762e-d3a7-4b15-968a-f066913aaeef
#   Source Lexical Simplicity: 4.3469
#   Generated Lexical Simplicity: 4.3898
#   Source Syntactic Grade: 20.4000 -> Syntactic Simplicity: 0.3200
#   Generated Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Grade Difference (source - generated): 2.5000
#
# Processed QuestionID: eeb73a24-dee7-4ecb-b902-95d25bdb5bca
#   Source Lexical Simplicity: 4.4481
#   Generated Lexical Simplicity: 4.4575
#   Source Syntactic Grade: 10.9000 -> Syntactic Simplicity: 0.6367
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): -6.5000
#
# Processed QuestionID: d594bdb3-481d-4474-8258-6d4aff3cb248
#   Source Lexical Simplicity: 4.4661
#   Generated Lexical Simplicity: 4.5348
#   Source Syntactic Grade: 29.2000 -> Syntactic Simplicity: 0.0267
#   Generated Syntactic Grade: 14.4000 -> Syntactic Simplicity: 0.5200
#   Grade Difference (source - generated): 14.8000
#
# Processed QuestionID: 6e8aea77-228e-4376-9245-bf200cde65f9
#   Source Lexical Simplicity: 4.2052
#   Generated Lexical Simplicity: 4.2685
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Grade Difference (source - generated): -1.9000
#
# Processed QuestionID: 709e6e57-3067-4f5e-8a16-5ed2fbcad0ba
#   Source Lexical Simplicity: 3.8308
#   Generated Lexical Simplicity: 4.4718
# ...
#   Grade Difference (source - generated): -2.9000
#
# Processed QuestionID: b4f11a2b-02b5-4f24-aa40-f38c5eb6a70c
#   Source Lexical Simplicity: 4.6319
#   Generated Lexical Simplicity: 4.5354
#   Source Syntactic Grade: 39.4000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): 21.8000
#
# Processed QuestionID: 2ac29bb2-ed85-48d1-9d78-a9f59f441e5c
#   Source Lexical Simplicity: 4.6368
#   Generated Lexical Simplicity: 4.5985
#   Source Syntactic Grade: 16.2000 -> Syntactic Simplicity: 0.4600
#   Generated Syntactic Grade: 19.7000 -> Syntactic Simplicity: 0.3433
#   Grade Difference (source - generated): -3.5000
#
# Processed QuestionID: cb613e70-17ee-4c90-b351-293dc22e5b3e
#   Source Lexical Simplicity: 4.3037
#   Generated Lexical Simplicity: 4.4358
#   Source Syntactic Grade: 27.3000 -> Syntactic Simplicity: 0.0900
#   Generated Syntactic Grade: 17.9000 -> Syntactic Simplicity: 0.4033
#   Grade Difference (source - generated): 9.4000
#
# Processed QuestionID: d7e4d216-552e-4c83-bf65-6ccd1a9fdbcb
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5589
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 16.8000 -> Syntactic Simplicity: 0.4400
#   Grade Difference (source - generated): 42.3000
#
# Processed QuestionID: 8cee6279-745c-4905-b95f-fa8b5d5fd8d8
#   Source Lexical Simplicity: 4.4618
#   Generated Lexical Simplicity: 4.4677
#   Source Syntactic Grade: 44.6000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.6000 -> Syntactic Simplicity: 0.4800
#   Grade Difference (source - generated): 29.0000
#
# Processed QuestionID: afb90589-4198-4b27-9ee2-eb95535ea731
#   Source Lexical Simplicity: 4.7322
#   Generated Lexical Simplicity: 4.4244
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 16.7000 -> Syntactic Simplicity: 0.4433
#   Grade Difference (source - generated): -1.7000
#
# Processed QuestionID: 796545cb-0c6f-4b3f-95f1-881adb884187
#   Source Lexical Simplicity: 4.6169
#   Generated Lexical Simplicity: 4.6139
#   Source Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Generated Syntactic Grade: 20.9000 -> Syntactic Simplicity: 0.3033
#   Grade Difference (source - generated): -5.9000
#
# Processed QuestionID: 939ac658-a817-4828-8d15-b7ecb812bcf6
#   Source Lexical Simplicity: 4.3587
#   Generated Lexical Simplicity: 4.4804
#   Source Syntactic Grade: 16.0000 -> Syntactic Simplicity: 0.4667
#   Generated Syntactic Grade: 16.8000 -> Syntactic Simplicity: 0.4400
#   Grade Difference (source - generated): -0.8000
#
# Processed QuestionID: 645e4501-671e-44fc-8cdf-926198c726ed
#   Source Lexical Simplicity: 4.7230
#   Generated Lexical Simplicity: 4.5405
#   Source Syntactic Grade: 33.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.3000 -> Syntactic Simplicity: 0.4900
#   Grade Difference (source - generated): 17.8000
#
# Processed QuestionID: 0ed241e7-9614-4900-891d-87660e854f47
#   Source Lexical Simplicity: 4.6994
#   Generated Lexical Simplicity: 4.6195
#   Source Syntactic Grade: 14.9000 -> Syntactic Simplicity: 0.5033
#   Generated Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Grade Difference (source - generated): -2.8000
#
# Processed QuestionID: 9fd81992-0406-4f07-a70e-7c774c4faca0
#   Source Lexical Simplicity: 4.7025
#   Generated Lexical Simplicity: 4.7131
#   Source Syntactic Grade: 32.5000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 15.9000 -> Syntactic Simplicity: 0.4700
#   Grade Difference (source - generated): 16.6000
#
# Processed QuestionID: 911bc97a-175c-48da-961e-4c509d67f16c
#   Source Lexical Simplicity: 4.1800
#   Generated Lexical Simplicity: 4.2700
#   Source Syntactic Grade: 24.7000 -> Syntactic Simplicity: 0.1767
#   Generated Syntactic Grade: 21.9000 -> Syntactic Simplicity: 0.2700
#   Grade Difference (source - generated): 2.8000
#
# Processed QuestionID: 536fbcc5-bec9-411f-ad0e-e5910eb0e105
#   Source Lexical Simplicity: 4.7085
#   Generated Lexical Simplicity: 4.7423
#   Source Syntactic Grade: 40.7000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 18.2000 -> Syntactic Simplicity: 0.3933
#   Grade Difference (source - generated): 22.5000
#
# Processed QuestionID: 19f21dd2-12e3-4b35-b2cc-8c35832a5770
#   Source Lexical Simplicity: 4.5054
#   Generated Lexical Simplicity: 4.4531
#   Source Syntactic Grade: 23.6000 -> Syntactic Simplicity: 0.2133
#   Generated Syntactic Grade: 22.1000 -> Syntactic Simplicity: 0.2633
#   Grade Difference (source - generated): 1.5000
#
# Processed QuestionID: 1ef8bc22-300d-4f63-aa26-44b07ff51f6f
#   Source Lexical Simplicity: 4.3623
#   Generated Lexical Simplicity: 4.3829
#   Source Syntactic Grade: 18.5000 -> Syntactic Simplicity: 0.3833
#   Generated Syntactic Grade: 20.3000 -> Syntactic Simplicity: 0.3233
#   Grade Difference (source - generated): -1.8000
#
# Processed QuestionID: 560e5c7d-7c38-4c98-9664-025b52e5b5a5
#   Source Lexical Simplicity: 4.3530
#   Generated Lexical Simplicity: 4.3175
#   Source Syntactic Grade: 24.2000 -> Syntactic Simplicity: 0.1933
#   Generated Syntactic Grade: 17.6000 -> Syntactic Simplicity: 0.4133
#   Grade Difference (source - generated): 6.6000
#
# Processed QuestionID: f0f66b8c-74c1-4b36-965e-4b1c49f47fbe
#   Source Lexical Simplicity: 4.7249
#   Generated Lexical Simplicity: 4.4413
#   Source Syntactic Grade: 18.7000 -> Syntactic Simplicity: 0.3767
#   Generated Syntactic Grade: 15.0000 -> Syntactic Simplicity: 0.5000
#   Grade Difference (source - generated): 3.7000
#
# Processed QuestionID: d5abdc79-0619-47bd-838f-cb0c5ca20501
#   Source Lexical Simplicity: 4.5725
#   Generated Lexical Simplicity: 4.5986
#   Source Syntactic Grade: 27.3000 -> Syntactic Simplicity: 0.0900
#   Generated Syntactic Grade: 16.5000 -> Syntactic Simplicity: 0.4500
#   Grade Difference (source - generated): 10.8000
#
# Processed QuestionID: 8e0f9ff0-5dc6-48d3-a209-dad0f752c4f0
#   Source Lexical Simplicity: 4.6482
#   Generated Lexical Simplicity: 4.6619
#   Source Syntactic Grade: 61.0000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Grade Difference (source - generated): 42.4000
#
# Processed QuestionID: 8ae1d1bd-de7b-4c90-b62c-ade701954740
#   Source Lexical Simplicity: 4.4372
#   Generated Lexical Simplicity: 4.5199
#   Source Syntactic Grade: 22.5000 -> Syntactic Simplicity: 0.2500
#   Generated Syntactic Grade: 18.5000 -> Syntactic Simplicity: 0.3833
#   Grade Difference (source - generated): 4.0000
#
# Processed QuestionID: cdaabedf-f073-4a86-b70a-343d550fc59b
#   Source Lexical Simplicity: 4.4205
#   Generated Lexical Simplicity: 4.5611
#   Source Syntactic Grade: 22.1000 -> Syntactic Simplicity: 0.2633
#   Generated Syntactic Grade: 15.6000 -> Syntactic Simplicity: 0.4800
#   Grade Difference (source - generated): 6.5000
#
# Processed QuestionID: bb3cd26c-2b7b-4685-bbb9-0176ce05c27d
#   Source Lexical Simplicity: 4.4417
#   Generated Lexical Simplicity: 4.2860
#   Source Syntactic Grade: 19.3000 -> Syntactic Simplicity: 0.3567
#   Generated Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Grade Difference (source - generated): 1.6000
#
# Processed QuestionID: 93d51e60-d7d0-47e1-8577-b996c9992f3c
#   Source Lexical Simplicity: 4.6497
#   Generated Lexical Simplicity: 4.6146
#   Source Syntactic Grade: 20.7000 -> Syntactic Simplicity: 0.3100
#   Generated Syntactic Grade: 16.1000 -> Syntactic Simplicity: 0.4633
#   Grade Difference (source - generated): 4.6000
#
# Processed QuestionID: 49a3f4b9-a03d-4410-b04c-87dbb7f20420
#   Source Lexical Simplicity: 4.4226
#   Generated Lexical Simplicity: 4.3463
#   Source Syntactic Grade: 14.2000 -> Syntactic Simplicity: 0.5267
#   Generated Syntactic Grade: 14.7000 -> Syntactic Simplicity: 0.5100
#   Grade Difference (source - generated): -0.5000
#
# Processed QuestionID: b12a05af-592b-44b2-8738-b4bde693545e
#   Source Lexical Simplicity: 4.1341
#   Generated Lexical Simplicity: 4.2803
#   Source Syntactic Grade: 18.6000 -> Syntactic Simplicity: 0.3800
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 0.8000
#
# Processed QuestionID: 48ce0db5-ec31-49a8-aad4-f3cfb4ea227b
#   Source Lexical Simplicity: 3.9106
#   Generated Lexical Simplicity: 4.2607
#   Source Syntactic Grade: 21.9000 -> Syntactic Simplicity: 0.2700
#   Generated Syntactic Grade: 16.2000 -> Syntactic Simplicity: 0.4600
#   Grade Difference (source - generated): 5.7000
#
# Processed QuestionID: 23f85bce-dc68-4e57-bf06-61a81501615b
#   Source Lexical Simplicity: 4.7611
#   Generated Lexical Simplicity: 4.4799
#   Source Syntactic Grade: 15.4000 -> Syntactic Simplicity: 0.4867
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): -4.0000
#
# Processed QuestionID: c06990bf-4431-41b4-b08c-fde41fa28639
#   Source Lexical Simplicity: 4.3286
#   Generated Lexical Simplicity: 4.3082
#   Source Syntactic Grade: 25.6000 -> Syntactic Simplicity: 0.1467
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): 7.8000
#
# Processed QuestionID: 21280d61-75bd-49f3-8a9d-3095952a9564
#   Source Lexical Simplicity: 4.7227
#   Generated Lexical Simplicity: 4.4024
#   Source Syntactic Grade: 18.9000 -> Syntactic Simplicity: 0.3700
#   Generated Syntactic Grade: 21.1000 -> Syntactic Simplicity: 0.2967
#   Grade Difference (source - generated): -2.2000
#
# Processed QuestionID: cb02ab56-69bb-4e29-a784-26d04b62b2b2
#   Source Lexical Simplicity: 4.7108
#   Generated Lexical Simplicity: 4.6892
#   Source Syntactic Grade: 15.4000 -> Syntactic Simplicity: 0.4867
#   Generated Syntactic Grade: 21.3000 -> Syntactic Simplicity: 0.2900
#   Grade Difference (source - generated): -5.9000
#
# Processed QuestionID: 9bf433fc-d5cf-4a3a-a268-361ef63bed40
#   Source Lexical Simplicity: 4.6670
#   Generated Lexical Simplicity: 4.6366
#   Source Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Generated Syntactic Grade: 16.9000 -> Syntactic Simplicity: 0.4367
#   Grade Difference (source - generated): 0.5000
#
# Processed QuestionID: 9cf91537-5920-4d76-ae75-5104e6edc6aa
#   Source Lexical Simplicity: 4.5863
#   Generated Lexical Simplicity: 4.5793
#   Source Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Generated Syntactic Grade: 20.4000 -> Syntactic Simplicity: 0.3200
#   Grade Difference (source - generated): -2.7000
#
# Processed QuestionID: 73d6160d-c531-4a4d-92f6-c59d9a45eccd
#   Source Lexical Simplicity: 4.5673
#   Generated Lexical Simplicity: 4.4300
#   Source Syntactic Grade: 18.4000 -> Syntactic Simplicity: 0.3867
#   Generated Syntactic Grade: 19.0000 -> Syntactic Simplicity: 0.3667
#   Grade Difference (source - generated): -0.6000
#
# Processed QuestionID: acc119aa-90fe-48a3-aa1a-f27a2c59292e
#   Source Lexical Simplicity: 4.4090
#   Generated Lexical Simplicity: 4.4445
#   Source Syntactic Grade: 22.2000 -> Syntactic Simplicity: 0.2600
#   Generated Syntactic Grade: 16.2000 -> Syntactic Simplicity: 0.4600
#   Grade Difference (source - generated): 6.0000
#
# Processed QuestionID: e7bbda46-8314-419b-80cb-854c3da70f15
#   Source Lexical Simplicity: 4.4943
#   Generated Lexical Simplicity: 4.5693
#   Source Syntactic Grade: 32.2000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): 14.8000
#
# Processed QuestionID: 7a341ffa-1fb3-4341-a12a-6b02d3b37d54
#   Source Lexical Simplicity: 4.6257
#   Generated Lexical Simplicity: 4.5850
#   Source Syntactic Grade: 59.1000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.7000 -> Syntactic Simplicity: 0.4100
#   Grade Difference (source - generated): 41.4000
#
# Processed QuestionID: 067edee2-7c81-47f1-9106-e4c7f5914347
#   Source Lexical Simplicity: 4.9750
#   Generated Lexical Simplicity: 4.5566
#   Source Syntactic Grade: 12.0000 -> Syntactic Simplicity: 0.6000
#   Generated Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Grade Difference (source - generated): -4.6000
#
# Processed QuestionID: 421b0e60-49ad-41fa-b60f-a4e9de4550c0
#   Source Lexical Simplicity: 4.3965
#   Generated Lexical Simplicity: 4.4889
#   Source Syntactic Grade: 51.4000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.3000 -> Syntactic Simplicity: 0.3567
#   Grade Difference (source - generated): 32.1000
#
# Processed QuestionID: a57e5f47-d2ff-4fe9-91d0-9d09bcc16865
#   Source Lexical Simplicity: 4.5147
#   Generated Lexical Simplicity: 4.5999
#   Source Syntactic Grade: 15.7000 -> Syntactic Simplicity: 0.4767
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): -2.1000
#
# Processed QuestionID: c611aeb1-561e-480b-9111-aafad84255fb
#   Source Lexical Simplicity: 4.2139
#   Generated Lexical Simplicity: 4.2781
#   Source Syntactic Grade: 23.0000 -> Syntactic Simplicity: 0.2333
#   Generated Syntactic Grade: 19.7000 -> Syntactic Simplicity: 0.3433
#   Grade Difference (source - generated): 3.3000
#
# Processed QuestionID: c7e8fd50-996d-4b00-bd0a-9e96ad13f8d3
#   Source Lexical Simplicity: 4.5378
#   Generated Lexical Simplicity: 4.5626
#   Source Syntactic Grade: 33.9000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): 16.5000
#
# Processed QuestionID: f8a99943-e6ce-486e-b7a7-ca4b2a893200
#   Source Lexical Simplicity: 4.7267
#   Generated Lexical Simplicity: 4.6046
#   Source Syntactic Grade: 26.2000 -> Syntactic Simplicity: 0.1267
#   Generated Syntactic Grade: 17.4000 -> Syntactic Simplicity: 0.4200
#   Grade Difference (source - generated): 8.8000
#
# Processed QuestionID: 4de042c1-8219-4c0f-b902-f89ae25e1fcf
#   Source Lexical Simplicity: 4.5604
#   Generated Lexical Simplicity: 4.5017
#   Source Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Generated Syntactic Grade: 16.7000 -> Syntactic Simplicity: 0.4433
#   Grade Difference (source - generated): -0.1000
#
# Processed QuestionID: 216deac1-2823-4c35-91c9-1062bb637e1f
#   Source Lexical Simplicity: 4.3955
#   Generated Lexical Simplicity: 4.3691
#   Source Syntactic Grade: 23.0000 -> Syntactic Simplicity: 0.2333
#   Generated Syntactic Grade: 17.3000 -> Syntactic Simplicity: 0.4233
#   Grade Difference (source - generated): 5.7000
#
# Processed QuestionID: 7897b253-8c88-4832-b7ca-98b10d58a47c
#   Source Lexical Simplicity: 4.5914
#   Generated Lexical Simplicity: 4.4774
#   Source Syntactic Grade: 37.7000 -> Syntactic Simplicity: 0.0000
#   Generated Syntactic Grade: 19.4000 -> Syntactic Simplicity: 0.3533
#   Grade Difference (source - generated): 18.3000
#
# Processed QuestionID: 8e64074a-43c0-4a21-bd2a-790f467f2229
#   Source Lexical Simplicity: 4.3648
#   Generated Lexical Simplicity: 4.3307
#   Source Syntactic Grade: 23.9000 -> Syntactic Simplicity: 0.2033
#   Generated Syntactic Grade: 18.3000 -> Syntactic Simplicity: 0.3900
#   Grade Difference (source - generated): 5.6000
#
# Processed QuestionID: 3ff1dce2-d38f-44c6-97a9-92160b9823f1
#   Source Lexical Simplicity: 3.7832
#   Generated Lexical Simplicity: 4.3790
#   Source Syntactic Grade: 12.8000 -> Syntactic Simplicity: 0.5733
#   Generated Syntactic Grade: 13.8000 -> Syntactic Simplicity: 0.5400
#   Grade Difference (source - generated): -1.0000
#
# Processed QuestionID: a7b7a450-24b1-45b2-bb2e-8dcad1f4a5fe
#   Source Lexical Simplicity: 4.6738
#   Generated Lexical Simplicity: 4.5186
#   Source Syntactic Grade: 18.5000 -> Syntactic Simplicity: 0.3833
#   Generated Syntactic Grade: 17.5000 -> Syntactic Simplicity: 0.4167
#   Grade Difference (source - generated): 1.0000
#
# Processed QuestionID: c7ed8533-d4de-4091-8449-23b30bc600c8
#   Source Lexical Simplicity: 4.2919
#   Generated Lexical Simplicity: 4.5267
#   Source Syntactic Grade: 16.6000 -> Syntactic Simplicity: 0.4467
#   Generated Syntactic Grade: 17.8000 -> Syntactic Simplicity: 0.4067
#   Grade Difference (source - generated): -1.2000
#
# Processed 446 items.
#
# Average Scores:
#   Lexical Simplicity:
#     Source: 4.4757
#     Generated: 4.4717
#   Syntactic Simplicity (converted from Flesch-Kincaid):
#     Average Source Grade: 25.7962 -> Simplicity: 0.2983
#     Average Generated Grade: 17.8379 -> Simplicity: 0.4054
#     Average Grade Difference (source - generated): 7.9583
